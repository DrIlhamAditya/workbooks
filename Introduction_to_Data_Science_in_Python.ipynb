# %%
# Import packages
import pandas as pd

# load the dataset
country = pd.read_csv("gapminder.csv")

# display the first 5 rows of dataset
print(country.head())
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
# Import packages
import pandas as pd

# load the dataset
country = pd.read_csv("gapminder.csv")

# get the dataset information
print(country.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB
# None

# %%
# Import packages
import pandas as pd

# load the dataset
country = pd.read_csv("gapminder.csv")

# Select the column item from gapminder
# Use dot notation
items = country.country

# Display the results
print(items)
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
# Import packages
import pandas as pd

# load the dataset
country = pd.read_csv("gapminder.csv")

# Fix the errors so that the code runs.
# Select the location column in credit_records
numeric_data = country["pop"]

# Display results
print(numeric_data)
# Out:
# 0        8425333
# 1        9240934
# 2       10267083
# 3       11537966
# 4       13079460
#           ...
# 1699     9216418
# 1700    10704340
# 1701    11404948
# 1702    11926563
# 1703    12311143
# Name: pop, Length: 1704, dtype: int64

# %%
# logical testing
# import packages
import pandas as pd

# load the dataset
country = pd.read_csv("gapminder.csv")
lifeExp_Afghanistan_1952 = 28.801
lifeExp_Afghanistan_1957 = 30.332

# is lifeExp_Afghanistan_1952 equal to lifeExp_Afghanistan_1957?
print(lifeExp_Afghanistan_1952 == lifeExp_Afghanistan_1957)

# is lifeExp_Afghanistan_1952 does not equal to lifeExp_Afghanistan_1957?
print(lifeExp_Afghanistan_1952 != lifeExp_Afghanistan_1957)
# Out:
# False
# True

# %%
# import packages
import pandas as pd

# load the dataset
country = pd.read_csv("gapminder.csv")

# select lifeExp under 50
lifeExp_under50 = country[country["lifeExp"] < 31.00]
print(lifeExp_under50)
# Out:
#            country continent  year  lifeExp      pop    gdpPercap
# 0      Afghanistan      Asia  1952   28.801  8425333   779.445314
# 1      Afghanistan      Asia  1957   30.332  9240934   820.853030
# 36          Angola    Africa  1952   30.015  4232095  3520.610273
# 552         Gambia    Africa  1952   30.000   284320   485.230659
# 1292        Rwanda    Africa  1992   23.599  7290203   737.068595
# 1344  Sierra Leone    Africa  1952   30.331  2143249   879.787736

# %%
# import packages
import pandas as pd

# load the dataset
country = pd.read_csv("gapminder.csv")

# select Zimbabwe only
zim = country[country["country"] == "Zimbabwe"]
print(zim)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1692  Zimbabwe    Africa  1952   48.451   3080907  406.884115
# 1693  Zimbabwe    Africa  1957   50.469   3646340  518.764268
# 1694  Zimbabwe    Africa  1962   52.358   4277736  527.272182
# 1695  Zimbabwe    Africa  1967   53.995   4995432  569.795071
# 1696  Zimbabwe    Africa  1972   55.635   5861135  799.362176
# 1697  Zimbabwe    Africa  1977   57.674   6642107  685.587682
# 1698  Zimbabwe    Africa  1982   60.363   7636524  788.855041
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
# preview new dataset
# import packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# load the dataset
world = pd.read_csv("countries-of-the-world.csv")

# display the 5th upper rows data
print(world.head(3))
# Out:
#         Country                               Region  Population  \
# 0  Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1      Albania   EASTERN EUROPE                          3581655
# 2      Algeria   NORTHERN AFRICA                        32930091
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0         23,06                             163,07               700.0
# 1         -4,93                              21,52              4500.0
# 2         -0,39                                 31              6000.0
#
#   Literacy (%) Phones (per 1000) Arable (%) Crops (%) Other (%) Climate  \
# ...

# %%
# making a scatterplot
# import packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# load the dataset
world = pd.read_csv("countries-of-the-world.csv")

# Create scatter plot with GDP on the x-axis and number of phones on the y-axis
sns.scatterplot(data=world, x="GDP ($ per capita)", y="Literacy (%)", hue="Region")

# Show plot
plt.show()

# %%
# making a scatterplot
# import packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# load the dataset
world = pd.read_csv("countries-of-the-world.csv")

# Create scatter plot with GDP on the x-axis and number of phones on the y-axis
sns.countplot(data=world, y="Region")

# Show plot
plt.show()

# %%
# import packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# load the dataset
world = pd.read_csv("gapminder.csv")

# Create a scatter plot of
sns.relplot(data=world, x="gdpPercap", y="lifeExp",
            kind="scatter",
            hue="continent")

# Show plot
plt.show()

# %%
# import packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# load the dataset
world = pd.read_csv("gapminder.csv")

# Create a scatter plot of
sns.relplot(data=world, x="pop", y="lifeExp",
            kind="scatter",
            hue="continent",
            style="continent")

# Show plot
plt.show()

# %%
# import packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# load the dataset
world = pd.read_csv("gapminder.csv")

# Create a boxplot
sns.catplot(data=world,
            y="gdpPercap",
            kind="box",
            hue="continent",
            )

# show plot
plt.show()
